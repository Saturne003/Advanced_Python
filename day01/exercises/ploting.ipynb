# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(1, 21, 1)
cpu_time_0 = [0.042000, 0.042000, 0.042000, 0.042000, 0.050000, 0.047000, 0.049000, 0.051000, 0.051000, 0.053000, 0.054000, .052000, 0.053000, 0.052000, 0.053000, 0.055000, 0.055000, 0.056000, 0.056000, 0.070000]
bandepasse_0 = [1816.522507, 1816.522507, 1816.522507, 816.522507, 1525.878906, 1623.275432, 1557.019292, 1495.959712, 1495.959712, 1439.508402, 1412.850839, 1467.191256, 1439.508402, 1467.191256, 1439.508402, 1387.162642, 1387.162642, 1362.391881, 1362.391881, 1089.913504]
cpu_time_2 = [0.018000, 0.019000, 0.019000, 0.023000, 0.020000, 0.026000, 0.025000, 0.028000, 0.028000, 0.028000, 0.030000, 0.028000, 0.031000, 0.028000, 0.028000, 0.028000, 0.028000, 0.030000, 0.028000, 0.030000]
bandepasse_2 = [4238.552517, 4015.470806, 4015.470806, 3317.128057, 3814.697266, 2934.382512, 3051.757812, 2724.783761, 2724.783761, 2724.783761, 2543.131510, 2724.783761, 2461.095010, 2724.783761, 2724.783761, 2724.783761, 2724.783761, 2543.131510, 2724.783761, 2543.131510]

# %%
plt.plot(t, cpu_time_0,label='-O0')
plt.plot(t, cpu_time_2,label='-O2')
plt.xlabel('stride')
plt.ylabel('CPU time (ms)')
plt.legend(loc='best') 
plt.show()

# %%
plt.plot(t, bandepasse_0,label='-O0')
plt.plot(t, bandepasse_2,label='-O2')
plt.xlabel('stride')
plt.ylabel('Effective bandwidth (MB/s)')
plt.legend(loc='best') 
plt.show()

# %% [markdown]
# D'après les graphes on remarque que lorsqu'on tant vers les grandes valeurs le nombre de calcul fait dans la compilation avec optimisation (-O2) devient important. Celle-ci devient plus coûteuse en temps que la compilation sans optimisation (-O0).
