# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.array([1, 2, 5, 10, 20, 50, 100])
cpu_time_0 = [4811.849000, 1686.482000, 1004.695000, 815.111000, 741.214000, 785.077000, 892.770000]
bandepasse_0 = [1.585543, 4.523852, 7.593742, 9.359945, 10.293106, 9.718021, 8.545756]

# %%
plt.plot(t, cpu_time_0,label='-O2')
plt.xlabel('Block size')
plt.ylabel('CPU time (ms)')
plt.legend(loc='best') 
plt.show()

# %%
plt.plot(t, bandepasse_0,label='-O2')
plt.xlabel('Block size')
plt.ylabel('Effective bandwidth (MB/s)')
plt.legend(loc='best') 
plt.show()
